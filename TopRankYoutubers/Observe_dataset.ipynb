# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Top_20_Youtuber_In_World.csv", encoding='ISO-8859-1')
df
# Out:
#     Rank              Username             Categories   Suscribers Country  \
# 0      1               tseries          Entertainment  249,500,000      IN
# 1      2               MrBeast          Entertainment  183,500,000      US
# 2      3             CoComelon                  Music  165,500,000      US
# 3      4              SETIndia          Entertainment  162,600,000      IN
# 4      5         KidsDianaShow                  Hobby  113,500,000      US
# 5      6             PewDiePie            Action_game  111,500,000      JP
# 6      7    LikeNastyaofficial  Lifestyle_(sociology)  107,500,000      US
# 7      8           VladandNiki                  Hobby  101,400,000      US
# 8      9       zeemusiccompany          Music_of_Asia   99,700,000      IN
# 9     10                   WWE          Entertainment   97,200,000      US
# 10    11             BLACKPINK                  Music   91,300,000      KR
# ...

# %%
df['Suscribers'] = df['Suscribers'].str.replace(',', '').astype(int)

# %%
df['Visits'] = df['Visits'].str.replace(',', '').astype(int)

# %%
df['Likes'] = df['Likes'].str.replace(',', '').astype(int)
df['Comments'] = df['Comments'].str.replace(',', '').astype(int)

# %%
df = df.head(10)

# %%
df.to_csv("Top_10_Youtuber_In_World.csv", index=False)
